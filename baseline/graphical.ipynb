# %%
import numpy as np 

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab    


import pandas as pd
from io import StringIO  
import csv  
from urllib.request import urlopen

from scipy.stats import mode

# %%
# RNN results
#pandas 画图
data = [978.56,543.36,351.52,288.02,249.97,235.02,230.58,222.41,209.56,215.62,217.58,211.44,199.08,198.33,195.72,194.15,197.37,178.87,188.76,192.56,193.45,187.25]
x = [100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200]

# %%
# lstm result
data_lstm = [878.56,443.36,361.52,231.65,220.14,161.52,147.68,155.82, 145.46,137.51,138.13,132.68,117.01,126.97,120.28,114.81,114.78,112.46,110.90,110.74,108.41,104.21,106.44,107.46,103.11,102.28,99.55,96.87,97.57,98.07,89.55,89.91,86.41,85.73,82.52,82.83,80.32, 78.93,77.40,75.88,73.82,75.72,74.39,75.76, 75.59,74.99]
x_lstm = [100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2600,2700,2800,2900,3000,3100,3200,3300,3400,3500,3600,3700,3800,3900,4000,4100,4200,4300,4400,4500,4600]

# %%
# GRU result
data_gru = [863.54,622.00,351.86,249.97,249.88,235.02,219.42, 210.22,206.19,207.30,200.50,195.43,193.63,195.15,196.05,182.31,187.58,182.12,176.35,170.71,180.07,171.65,165.54]
x_gru = [100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300]

# %%
plt.plot(x, data, color = 'r',label = 'RNN')
plt.plot(x_lstm, data_lstm, color = 'g',label = 'LSTM')
plt.plot(x_gru, data_gru, color = 'y',label = 'GRU')
plt.xlabel("global epoch")  
plt.ylabel("perplecisty")  
plt.title("Pre-train Generator use different RNN cells")  
    
plt.show()

# %%
## different learning rate

# %%
# GRU
data = [193.63,87.59,86.78,68.99,73.80,66.76,51.11,49.53,40.49,38.14,34.94,34.64]
x = [0.5000 ,0.4950, 0.4901,0.4851,0.4803,0.4755,0.4707,0.4660,0.4614, 0.4568,0.4522 ,0.4477]

# %%
# LSTM
data_l = [75.76,53.11,51.78,44.25,40.88,35.87,34.72,32.49,32.74,30.16,29.68,30.31]
x_l = [0.5000 ,0.4950, 0.4901,0.4851,0.4803,0.4755,0.4707,0.4660,0.4614, 0.4568,0.4522 ,0.4477]

# %%
plt.plot(x, data, color = 'r',label = 'GRU')
plt.plot(x_l, data_l, color = 'g',label = 'LSTM')

plt.xlabel("leaning rate")  
plt.ylabel("perplecisty")  
plt.title("Learing rate decay")  

ax = plt.gca()
ax.invert_xaxis()
    
plt.show(gca) 
#plt.imshow(img[:-1])
